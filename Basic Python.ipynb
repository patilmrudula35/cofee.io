# %% [markdown]
# ## Write a Python program to check whether a file exists.

# %%
import os.path

# %%
os.path.exists('dummyfile.txt')
# Out:
# True

# %% [markdown]
# ## Write a Python to call an external command in Python

# %% [markdown]
# ## Write a python program to find out the number of CPUs using

# %%
Count = os.cpu_count()
print("Number of CPUs using:", Count)
# Out:
# Number of CPUs using: 4

# %% [markdown]
# ## Write a Python program to list all files in a directory in Python.

# %%
dir_list = os.listdir('D://python')
print(dir_list)
# Out:
# ['Count_Alpha.py', 'Exp', 'Group Activity', 'largest_two.py', 'Voter_App']

# %% [markdown]
# ## Write a python program to access environment variables

# %%
print(os.environ)
# Out:
# environ({'ALLUSERSPROFILE': 'C:\\ProgramData', 'APPDATA': 'C:\\Users\\Sameer\\AppData\\Roaming', 'COMMONPROGRAMFILES': 'C:\\Program Files\\Common Files', 'COMMONPROGRAMFILES(X86)': 'C:\\Program Files (x86)\\Common Files', 'COMMONPROGRAMW6432': 'C:\\Program Files\\Common Files', 'COMPUTERNAME': 'DESKTOP-NUKU6U1', 'COMSPEC': 'C:\\WINDOWS\\system32\\cmd.exe', 'DRIVERDATA': 'C:\\Windows\\System32\\Drivers\\DriverData', 'FPS_BROWSER_APP_PROFILE_STRING': 'Internet Explorer', 'FPS_BROWSER_USER_PROFILE_STRING': 'Default', 'HOMEDRIVE': 'C:', 'HOMEPATH': '\\Users\\Sameer', 'INTELLIJ IDEA COMMUNITY EDITION': 'C:\\Program Files\\JetBrains\\IntelliJ IDEA Community Edition 2021.2.1\\bin;', 'LOCALAPPDATA': 'C:\\Users\\Sameer\\AppData\\Local', 'LOGONSERVER': '\\\\DESKTOP-NUKU6U1', 'NUMBER_OF_PROCESSORS': '4', 'ONEDRIVE': 'C:\\Users\\Sameer\\OneDrive', 'OS': 'Windows_NT', 'PATH': 'C:\\Users\\Sameer\\anaconda3;C:\\Users\\Sameer\\anaconda3\\Library\\mingw-w64\\bin;C:\\Users\\Sameer\\anaconda3\\Library\
# ...

# %% [markdown]
# ##  Write a Python program to get the current username

# %%
print(os.getlogin())
# Out:
# Sameer

# %% [markdown]
# ## Write a program to get execution time for a Python method.

# %% [markdown]
# ## Write a Python program to get an absolute file path.

# %%
os.path.abspath('dummyfile.txt')
# Out:
# 'C:\\Users\\Sameer\\Data Science Bootcamp\\dummyfile.txt'

# %% [markdown]
# ##  Write a Python program to get file creation and modification date/times

# %%
import time

# %%
print("Created: %s" % time.ctime(os.path.getctime("dummyfile.txt")))
print("Last modified: %s" % time.ctime(os.path.getmtime("dummyfile.txt")))
# Out:
# Created: Mon Aug 22 20:36:46 2022
# Last modified: Mon Aug 22 20:36:46 2022

# %% [markdown]
# ## Write a Python program to sort three integers without using conditional statements and loops.

# %%
n1 = int(input("Enter first number: "))
n2 = int(input("Enter second number: "))
n3 = int(input("Enter third number: "))

a1 = min(n1, n2, n3)
a3 = max(n1, n2, n3)
a2 = (n1 + n2 + n3) - a1 - a3
print("Numbers in sorted order:", a1, a2, a3)
# Out:
# Enter first number: 35
# Enter second number: 47
# Enter third number: 21
# Numbers in sorted order: 21 35 47

# %% [markdown]
# ## Write a Python program to sort files by date.

# %%
import glob

files = glob.glob("*.txt")
files.sort(key=os.path.getmtime)
print("\n".join(files))
# Out:
# dummyfile.txt
# dummyfil2.txt

# %% [markdown]
# ## Write a Python program to get the command-line arguments (name of the script, the number of arguments, arguments) passed to a script.

# %%
import sys
print("Name of the script:",sys.argv[0])
print("Number of arguments:",len(sys.argv))
print("Argument List:",str(sys.argv))

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Write a Python program to find the available built-in modules.

# %%
print(sys.builtin_module_names)
# Out:
# ('_abc', '_ast', '_bisect', '_blake2', '_codecs', '_codecs_cn', '_codecs_hk', '_codecs_iso2022', '_codecs_jp', '_codecs_kr', '_codecs_tw', '_collections', '_contextvars', '_csv', '_datetime', '_functools', '_heapq', '_imp', '_io', '_json', '_locale', '_lsprof', '_md5', '_multibytecodec', '_opcode', '_operator', '_pickle', '_random', '_sha1', '_sha256', '_sha3', '_sha512', '_signal', '_sre', '_stat', '_statistics', '_string', '_struct', '_symtable', '_thread', '_tracemalloc', '_warnings', '_weakref', '_winapi', '_xxsubinterpreters', 'array', 'atexit', 'audioop', 'binascii', 'builtins', 'cmath', 'errno', 'faulthandler', 'gc', 'itertools', 'marshal', 'math', 'mmap', 'msvcrt', 'nt', 'parser', 'sys', 'time', 'winreg', 'xxsubtype', 'zlib')

# %% [markdown]
# ## Write a Python program to get the size of an object in bytes.

# %%
print(sys.getsizeof(set()))   #size of set is 216
print(sys.getsizeof([]))    #size of list is 56
# Out:
# 216
# 56

# %% [markdown]
# ##  Write a Python program to get the current value of the recursion limit.

# %%
print(sys.getrecursionlimit())
# Out:
# 3000

# %% [markdown]
# ## Write a Python program to count the number occurrence of a specific character in a string.

# %%
string = "This is a dummy string"

print("Occurence of i in above string: ", string.count('i'))
# Out:
# Occurence of i in above string:  3

# %% [markdown]
# ## Write a Python program to get the system time.

# %%
print(time.ctime())
# Out:
# Mon Aug 22 21:25:17 2022

# %% [markdown]
# ## Write a Python program to clear the screen or terminal.

# %%
os.system('cls')
# Out:
# 0

# %% [markdown]
# ## Write a Python program to get the name of the host on which the routine is running

# %%
import socket

# %%
print("Name of host:", socket.gethostname())
# Out:
# Name of host: DESKTOP-NUKU6U1

# %% [markdown]
# ## Write a Python program to access and print a URL's content to the console.

# %%
import requests
data = requests.get('https://twitter.com')
print(data.text)
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en">
# <meta charset="utf-8" />
# ...
